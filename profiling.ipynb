# %%
import pstats
stats = pstats.Stats('./prof3.prof')

# %%
stats.sort_stats(pstats.SortKey.TIME).print_stats()
# Out:
# Mon Oct 16 12:21:17 2023    ./prof3.prof
#
#          12577674 function calls (12136839 primitive calls) in 115.755 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       284   32.648    0.115   32.648    0.115 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      2368   26.521    0.011   26.594    0.011 /home/sterlind/miniconda3/envs/tima2/lib/python3.10/site-packages/soundfile.py:1346(_cdata_io)
#     32724    9.131    0.000    9.131    0.000 {built-in method torch.conv1d}
#     17067    3.190    0.000    3.190    0.000 {built-in method torch.conv2d}
#      2368    3.089    0.001   42.101    0.018 /home/sterlind/projects/tima3/speech-resynthesis/dataset.py:226(__getitem__)
#      2521    2.795    0.001    3.868    0.002 /home/sterlind/miniconda3/envs/tima2/lib/python3.10/site-packages/librosa/filters.py:127(mel)
# ...

# %%
# %load_ext autoreload
# %autoreload 2

from dataset import get_yaapt_f0
import soundfile

wav, sr = soundfile.read('/home/sterlind/projects/tima3/scotus/datasets/scotus_flacs/1995.94-1809-t01.532.1-70-0.flac')

# %%
out = get_yaapt_f0(wav[None])[0, 0]
min(out[out > 0.])
# Out:
# 60.836501901140686

# %%
import librosa
import numpy as np
def get_pyin_f0(audio, rate=16000):
    out = librosa.pyin(
        audio,
        fmin=60.,
        fmax=1800.,
        sr=rate,
        frame_length=20)
    out[np.isnan(out)] = 0.
    return out

f0, _, _ = librosa.pyin(wav, fmin=60, fmax=1800, sr=sr)
f0.shape
# Out:
# (449,)
